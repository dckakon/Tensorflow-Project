# %% [markdown]
# <a href="https://colab.research.google.com/github/Debobrata-Chakraborty-Kakon/Tensorflow--Hand-Written-Digit-Classification/blob/master/Y_value_predicting_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
x=np.array([1,2,3,4,5,6,7],dtype=float)

# %%
y=np.array([11,12,13,14,15,16,17],dtype=float)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 176ms/step - loss: 185.0089
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 74.6771
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 36.9788
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 24.0399
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 19.5416
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 17.9212
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 17.2824
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 16.9789
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 16.7903
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 16.6416
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 16.5071
# Epoch 12/500
# ...

# %%
print(model.predict([9]))
# Out:
# [[20.124382]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pickle

# %%
import os.path

# %%
if os.path.isfile('/content/drive/MyDrive/Dataset/Animal-10/model_helloworld.h5') is False:
  model.save('/content/drive/MyDrive/Dataset/Animal-10/model_helloworld.h5')

# %%
from tensorflow.keras.models import load_model

# %%
new_model=load_model('/content/drive/MyDrive/Dataset/Animal-10/model_helloworld.h5')

# %%
new_model.predict([10])
# Out:
# array([[21.370203]], dtype=float32)
